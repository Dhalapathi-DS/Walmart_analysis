# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhalapathi-DS/Walmart_analysis/blob/main/walmart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Dataset Import and Initial Data Analysis**

# %%
data=pd.read_csv('walmart_data.csv')
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                               2               0                 3      8370
# ...

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category',
#        'Purchase'],
#       dtype='object')

# %%
data.size
# Out:
# 5500680

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (550068, 10)

# %%
data.dtypes
# Out:
# User_ID                        int64
# Product_ID                    object
# Gender                        object
# Age                           object
# Occupation                     int64
# City_Category                 object
# Stay_In_Current_City_Years    object
# Marital_Status                 int64
# Product_Category               int64
# Purchase                       int64
# dtype: object

# %% [markdown]
# **Insights**
#
# The dataset consists of 5,500,680 entries and 10 attributes, including User_ID, Product_ID, Gender, Age, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category, and Purchase. It has a 2-dimensional structure with a shape of (550068, 10) and a total of 10 columns.

# %% [markdown]
# **Detecting Null Values**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category            550068 non-null  int64
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 42.0+ MB

# %%
data.isnull().value_counts()
# Out:
# User_ID  Product_ID  Gender  Age    Occupation  City_Category  Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# False    False       False   False  False       False          False                       False           False             False       550068
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %% [markdown]
# **Insights**
#
# The dataset contains a total of 550,068 entries across 10 columns, with all columns showing non-null counts of 550,068, indicating that there are no missing values in any of the attributes. This completeness ensures that the dataset is fully populated for analysis without the need for imputation or removal of null entries.

# %% [markdown]
# **Non-Graphical Analysis**

# %%
print("Gender Distribution:")
print(data['Gender'].value_counts())

print("\nAge Distribution:")
print(data['Age'].value_counts())

print("\nCity Category Distribution:")
print(data['City_Category'].value_counts())
# Out:
# Gender Distribution:
# Gender
# M    414259
# F    135809
# Name: count, dtype: int64
#
# Age Distribution:
# Age
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: count, dtype: int64
#
# City Category Distribution:
# City_Category
# B    231173
# C    171175
# A    147720
# Name: count, dtype: int64

# %% [markdown]
# **Insights**
#
# The gender distribution in the dataset reveals a significant imbalance, with 414,259 male (M) customers compared to 135,809 female (F) customers, indicating a predominance of male shoppers. The age distribution shows that the largest group of customers falls within the 26-35 age range (219,587), followed by the 36-45 range (110,013), suggesting that younger adults are the primary consumers. In terms of city category, customers from category B (231,173) represent the largest segment, followed by category C (171,175) and category A (147,720), reflecting varied market engagement across different city classifications.

# %% [markdown]
# **Boxplots and Outliers**

# %%
data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category  \
# count  5.500680e+05  550068.000000   550068.000000     550068.000000
# mean   1.003029e+06       8.076707        0.409653          5.404270
# std    1.727592e+03       6.522660        0.491770          3.936211
# min    1.000001e+06       0.000000        0.000000          1.000000
# 25%    1.001516e+06       2.000000        0.000000          1.000000
# 50%    1.003077e+06       7.000000        0.000000          5.000000
# 75%    1.004478e+06      14.000000        1.000000          8.000000
# max    1.006040e+06      20.000000        1.000000         20.000000
#
#             Purchase
# count  550068.000000
# mean     9263.968713
# std      5023.065394
# min        12.000000
# 25%      5823.000000
# 50%      8047.000000
# 75%     12054.000000
# max     23961.000000

# %%
# boxplot for Purchase
plt.figure(figsize=(12, 6))
sns.boxplot(y='Purchase', data=data, palette='Set2')
plt.title('Boxplot of Purchase Amount Distribution')
plt.ylabel('Purchase Amount')
plt.grid()
plt.show()
# Out:
# <ipython-input-13-4d3d6e520417>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y='Purchase', data=data, palette='Set2')  # Create boxplot for Purchase

# %% [markdown]
# **Insights**
#
# The boxplot analysis for purchase amounts reveals a range from 5823 to 12054, with a minimum spending of 12 and a maximum of 23961. This indicates a significant disparity in spending, with some transactions being substantially higher than others. The presence of outliers, particularly the maximum value, suggests that while most customers spend within the specified range, a few make exceptionally large purchases. Overall, this highlights the variability in spending behavior among customers.

# %%
purchase_stats = data.groupby('Gender')['Purchase'].describe()
purchase_stats
# Out:
#            count         mean          std   min     25%     50%      75%  \
# Gender
# F       135809.0  8734.565765  4767.233289  12.0  5433.0  7914.0  11400.0
# M       414259.0  9437.526040  5092.186210  12.0  5863.0  8098.0  12454.0
#
#             max
# Gender
# F       23959.0
# M       23961.0

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Gender', y='Purchase', data=data, palette='Set2')
plt.title('Boxplot of Purchase Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Purchase Amount')
plt.grid()
plt.show()
# Out:
# <ipython-input-15-f9e71d586a6f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='Purchase', data=data, palette='Set2')

# %% [markdown]
# **Insights**
#
#
# Males have a higher purchase count (414,259) and a mean spending of 9,437.53 compared to females (135,809), who have a mean spending of 8,734.57. The maximum purchase for both genders is similar, with males reaching 23,961 and females 23,959. This indicates that male customers are not only more numerous but also spend more on average than female customers. Overall, the data suggests a significant gender disparity in purchasing behavior.

# %%
purchase_stats = data.groupby('Marital_Status')['Purchase'].describe()
purchase_stats
# Out:
#                    count         mean          std   min     25%     50%  \
# Marital_Status
# 0               324731.0  9265.907619  5027.347859  12.0  5605.0  8044.0
# 1               225337.0  9261.174574  5016.897378  12.0  5843.0  8051.0
#
#                     75%      max
# Marital_Status
# 0               12061.0  23961.0
# 1               12042.0  23961.0

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Marital_Status', y='Purchase', data=data, palette='Set2')
plt.title('Boxplot of Purchase Amount by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Purchase Amount')
plt.grid()
plt.show()
# Out:
# <ipython-input-17-a1387667c8f7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Marital_Status', y='Purchase', data=data, palette='Set2')

# %% [markdown]
# **Insights**
#
# The purchase data indicates that single customers (Marital_Status = 0) have a slightly higher mean spending of 9,265.91 compared to married customers (Marital_Status = 1), who average 9,261.17. Both groups have similar purchase distributions, with a minimum of 12 and a maximum of 23,961. The count of single customers is higher at 324,731 compared to 225,337 for married customers. Overall, the spending behavior is comparable between the two marital statuses.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Product_Category', y='Purchase', data=data, palette='Set2')
plt.title('Boxplot of Purchase Amount by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Purchase Amount')
plt.grid()
plt.show()
# Out:
# <ipython-input-18-eb8063c38adf>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Product_Category', y='Purchase', data=data, palette='Set2')

# %% [markdown]
# **Data Exploration**

# %%
data['Age'] = pd.Categorical(data['Age'], categories=['0-17', '18-25', '26-35', '36-45', '46-50', '51-55', '55+'], ordered=True)

# Set up the matplotlib figure
plt.figure(figsize=(14, 6))

# Histogram for Purchase
plt.subplot(1, 2, 1)
sns.histplot(data['Purchase'], bins=30, kde=True)
plt.title('Histogram of Purchase Amounts')
plt.xlabel('Purchase Amount')
plt.ylabel('Frequency')

# Histogram for Age
plt.subplot(1, 2, 2)
sns.histplot(data['Age'].cat.codes, bins=7)  # Convert Age categories to numeric codes for histogram
plt.title('Histogram of Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.xticks(ticks=range(len(data['Age'].cat.categories)), labels=data['Age'].cat.categories, rotation=45)

# Show the plots
plt.tight_layout()
plt.show()

# %%
#figure for the plots
plt.figure(figsize=(18, 5))

# Countplot for Age
plt.subplot(1, 3, 1)
sns.countplot(x='Age', data=data)
plt.title('Count of Users by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')

# Countplot for Gender
plt.subplot(1, 3, 2)
sns.countplot(x='Gender', data=data)
plt.title('Count of Users by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

# Countplot for City Category
plt.subplot(1, 3, 3)
sns.countplot(x='City_Category', data=data)
plt.title('Count of Users by City Category')
plt.xlabel('City Category')
plt.ylabel('Count')

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# Age Group:The age group of 26-35 stands out with a significantly higher purchase count exceeding 200,000, indicating strong spending behavior. In contrast, the age groups 18-25 and 36-45 show similar counts, each around 100,000, suggesting a more moderate purchasing trend. The remaining age categories exhibit even lower counts, highlighting a distinct preference among the 26-35 demographic. This analysis emphasizes the importance of targeting marketing efforts toward this age group.
#
# Gender:The dataset reveals a significant gender imbalance in purchasing behavior, with males accounting for 414,259 transactions compared to females at 135,809. This indicates that male customers are more predominant in the purchasing data.
#
# City category:The distribution of purchases across city categories indicates that City B has the highest number of transactions at 231,173, followed by City C with 171,175. City A has the lowest volume at 147,720. This suggests that City B is a key market for sales and should be a focus for marketing efforts.

# %%
average_purchase = data.groupby(['Age', 'City_Category'], observed=True)['Purchase'].mean().reset_index()
heatmap_data = average_purchase.pivot(index='Age', columns='City_Category', values='Purchase')
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.1f', linewidths=.5)
plt.title('Heatmap of Average Purchase Amount by Age and City Category')
plt.xlabel('City Category')
plt.ylabel('Age Groups')
plt.show()

# %% [markdown]
# **Insights**
#
# The heatmap reveals distinct spending patterns across city categories and age groups. City C consistently shows the highest average purchase amounts, particularly for the 46-50 age group. In contrast, City A exhibits the lowest spending across all age groups. The 46-50 age group consistently outspends other groups, likely due to factors like established careers and financial stability.

# %% [markdown]
# **Confidence Intervals**

# %% [markdown]
# **Confidence Interval for Gender**

# %%
female_purchase = data[data['Gender'] == 'F']['Purchase']
male_purchase = data[data['Gender'] == 'M']['Purchase']
mean_female = np.mean(female_purchase)
std_female = np.std(female_purchase)
mean_male = np.mean(male_purchase)
std_male = np.std(male_purchase)
print(f"Mean Female Purchase: {mean_female}, Std Dev: {std_female}")
print(f"Mean Male Purchase: {mean_male}, Std Dev: {std_male}")
# Out:
# Mean Female Purchase: 8734.565765155476, Std Dev: 4767.215738016988
# Mean Male Purchase: 9437.526040472265, Std Dev: 5092.180063635943

# %%
def confidence_interval(mean, std_dev, n):
    z_score = 1.96
    margin_of_error = z_score * (std_dev / np.sqrt(n))
    return (mean - margin_of_error, mean + margin_of_error)
ci_female = confidence_interval(mean_female, std_female, len(female_purchase))
ci_male = confidence_interval(mean_male, std_male, len(male_purchase))
print(f"95% CI for Female Purchases: {ci_female}")
print(f"95% CI for Male Purchases: {ci_male}")
# Out:
# 95% CI for Female Purchases: (8709.21117458943, 8759.92035572152)
# 95% CI for Male Purchases: (9422.019181136464, 9453.032899808066)

# %%
def bootstrap_ci(data, sample_size, n_bootstrap=1000, confidence=0.95):
    bootstrapped_means = []
    for _ in range(n_bootstrap):
        sample = np.random.choice(data, size=sample_size, replace=True)
        bootstrapped_means.append(np.mean(sample))
    lower = np.percentile(bootstrapped_means, (1 - confidence) / 2 * 100)
    upper = np.percentile(bootstrapped_means, (1 + confidence) / 2 * 100)
    return (lower, upper)

# %%
sample_sizes = [300, 3000, 30000]
for size in sample_sizes:
    ci_female_bootstrap = bootstrap_ci(female_purchase, size)
    ci_male_bootstrap = bootstrap_ci(male_purchase, size)

    print(f"\nBootstrapped 95% CI for Female Purchases (Sample Size = {size}): {ci_female_bootstrap}")
    print(f"Bootstrapped 95% CI for Male Purchases (Sample Size = {size}): {ci_male_bootstrap}")
# Out:
# Bootstrapped 95% CI for Female Purchases (Sample Size = 300): (8209.605833333333, 9293.225166666667)
# Bootstrapped 95% CI for Male Purchases (Sample Size = 300): (8852.696333333333, 10002.23375)
#
# Bootstrapped 95% CI for Female Purchases (Sample Size = 3000): (8565.55645, 8912.829875)
# Bootstrapped 95% CI for Male Purchases (Sample Size = 3000): (9244.74235, 9635.987808333333)
#
# Bootstrapped 95% CI for Female Purchases (Sample Size = 30000): (8677.399328333333, 8787.3065575)
# Bootstrapped 95% CI for Male Purchases (Sample Size = 30000): (9377.588983333333, 9493.171478333334)

# %% [markdown]
# **Insights**
#
# The bootstrapped 95% confidence intervals (CIs) for purchases indicate that female spending narrows with larger sample sizes. For a sample size of 300, the CI is (8223.05, 9310.93), while it narrows to (8567.71, 8907.81) for 3000, and (8679.97, 8788.92) for 30000. Conversely, male spending shows consistently higher CIs: (8902.57, 10025.87) for 300, (9251.80, 9626.28) for 3000, and (9382.92, 9497.71) for 30000. This trend indicates that male customers typically spend more per transaction than their female counterparts. Additionally, the narrowing confidence intervals reflect increasing precision in the estimates as sample sizes grow. Overall, the analysis highlights a significant difference in spending behavior between genders, with males leading in average purchase amounts across all sample sizes.

# %% [markdown]
# **Confidence Interval for Marital Status**

# %%
marital_status_data = data.groupby('Marital_Status')['Purchase'].apply(list).to_dict()
def bootstrap_confidence_interval(data, confidence=0.95, n_bootstraps=1000):
    bootstrapped_means = []
    for _ in range(n_bootstraps):
        sample = np.random.choice(data, size=len(data), replace=True)
        bootstrapped_means.append(np.mean(sample))
    lower = np.percentile(bootstrapped_means, (1 - confidence) / 2 * 100)
    upper = np.percentile(bootstrapped_means, (1 + confidence) / 2 * 100)
    return lower, upper

def calculate_ci_for_marital_status(marital_status_data, sample_sizes):
    ci_results = {}
    for status, purchases in marital_status_data.items():
        ci_results[status] = {}
        for size in sample_sizes:
            sample = np.random.choice(purchases, size=size, replace=True)
            ci = bootstrap_confidence_interval(sample)
            ci_results[status][size] = ci
    return ci_results

sample_sizes = [300, 3000, 30000]

ci_marital_status_sizes = calculate_ci_for_marital_status(marital_status_data, sample_sizes)
for status, ci_sizes in ci_marital_status_sizes.items():
    print(f"\nConfidence Intervals for Marital Status '{status}':")
    for size, ci in ci_sizes.items():
        print(f"Sample Size {size}: {ci}")
# Out:
# Confidence Intervals for Marital Status '0':
# Sample Size 300: (8871.807083333333, 9985.619333333334)
# Sample Size 3000: (9097.699616666667, 9459.288349999999)
# Sample Size 30000: (9215.240209166666, 9326.942798333333)
#
# Confidence Intervals for Marital Status '1':
# Sample Size 300: (8800.7785, 9850.453583333334)
# Sample Size 3000: (9208.547458333334, 9572.21025)
# Sample Size 30000: (9219.480190833332, 9333.528825000001)

# %% [markdown]
# **Insights**
#
# The bootstrapped 95% confidence intervals (CIs) for purchases based on marital status indicate differing spending behaviors. For marital status '0', the CI for a sample size of 300 is (8074.48, 9176.40), which tightens to (9068.16, 9435.12) with 3000 samples, and further narrows to (9194.76, 9303.96) for a sample size of 30000. In contrast, marital status '1' shows higher spending, with a CI of (8862.71, 10059.89) for 300 samples, (9058.58, 9431.34) for 3000, and (9197.73, 9312.01) for 30000. This suggests that married individuals (status '1') generally spend more per transaction compared to their single counterparts (status '0'). The narrowing of confidence intervals across increasing sample sizes indicates improved precision in estimates. Overall, the analysis highlights a significant difference in spending behavior based on marital status, with married individuals consistently leading in average purchases.

# %% [markdown]
# **Confidence Interval for Age group**

# %%
age_data = data.groupby('Age')['Purchase'].apply(list).to_dict()
def bootstrap_confidence_interval(data, confidence=0.95, n_bootstraps=1000):
    bootstrapped_means = []
    for _ in range(n_bootstraps):
        sample = np.random.choice(data, size=len(data), replace=True)
        bootstrapped_means.append(np.mean(sample))
    lower = np.percentile(bootstrapped_means, (1 - confidence) / 2 * 100)
    upper = np.percentile(bootstrapped_means, (1 + confidence) / 2 * 100)
    return lower, upper
def calculate_ci_for_age(age_data, sample_sizes):
    ci_results = {}
    for age_group, purchases in age_data.items():
        ci_results[age_group] = {}
        for size in sample_sizes:
            sample = np.random.choice(purchases, size=size, replace=True)
            ci = bootstrap_confidence_interval(sample)
            ci_results[age_group][size] = ci
    return ci_results
sample_sizes = [300, 3000, 30000]
ci_age_sizes = calculate_ci_for_age(age_data, sample_sizes)
for age_group, ci_sizes in ci_age_sizes.items():
    print(f"\nConfidence Intervals for Age Group '{age_group}':")
    for size, ci in ci_sizes.items():
        print(f"Sample Size {size}: {ci}")
# Out:
# <ipython-input-27-98188aac8082>:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_data = data.groupby('Age')['Purchase'].apply(list).to_dict()
# Confidence Intervals for Age Group '0-17':
# Sample Size 300: (8588.221083333334, 9708.070583333332)
# Sample Size 3000: (9019.679158333332, 9377.487983333333)
# Sample Size 30000: (8903.3414025, 9019.01558)
#
# Confidence Intervals for Age Group '18-25':
# Sample Size 300: (8846.346083333334, 10029.1255)
# Sample Size 3000: (9002.971441666667, 9372.371525)
# Sample Size 30000: (9139.47483, 9251.3532225)
#
# Confidence Intervals for Age Group '26-35':
# Sample Size 300: (8690.400166666666, 9814.065666666665)
# Sample Size 3000: (9127.764224999999, 9483.876975000001)
# Sample Size 30000: (9242.000288333335, 9351.608159166666)
#
# ...

# %% [markdown]
# **Insights**
#
# The bootstrapped 95% confidence intervals (CIs) for purchases across various age groups reveal distinct spending patterns. For the age group '0-17', the CI for a sample size of 300 is (8545.90, 9666.56), narrowing to (8753.20, 9103.74) with 3000 samples, and tightening further to (8852.80, 8970.14) for 30000 samples. The '18-25' age group has a CI of (8565.02, 9747.34) for 300, (9104.16, 9457.27) for 3000, and (9116.77, 9230.22) for 30000 samples.
#
# For the '26-35' age group, the confidence intervals start at (8405.47, 9450.30) for 300 samples, shift to (9184.89, 9528.48) for 3000, and remain similar at (9179.55, 9293.62) for 30000 samples. The '36-45' age group shows a broader range, with a CI of (9343.98, 10437.87) for 300 samples, which narrows down to (9095.47, 9421.82) for 3000, and further to (9277.90, 9388.08) for 30000 samples.
#
# For older groups, the '46-50' age group's CIs start at (8280.66, 9471.53) for 300, (9006.61, 9373.49) for 3000, and (9168.26, 9282.66) for 30000. The '51-55' group indicates a CI of (9217.21, 10301.30) for 300, refining to (9344.25, 9711.65) for 3000, and (9489.91, 9606.73) for 30000. Lastly, the '55+' age group shows a CI of (8783.52, 9948.43) for 300, (9070.61, 9424.24) for 3000, and (9285.02, 9400.38) for 30000. Overall, younger age groups tend to have lower purchase amounts, while older groups show a wider range and potential for higher spending per transaction.

# %% [markdown]
# **Recommendations**
#
# **Targeted Marketing Campaigns:** Given that males have a higher average purchase amount and count, Walmart should tailor marketing campaigns that specifically target male consumers, especially for high-ticket items or promotions that appeal to this demographic.
#
# **Promotions for Younger Consumers:**With younger age groups (18-25) showing significant purchase activity, Walmart could consider targeted promotions or discounts for this demographic, perhaps through loyalty programs or social media campaigns that resonate with their interests.
#
# **Enhancing Offerings for Age Group 26-35:** Since the age group of 26-35 shows the highest count of purchases, Walmart should focus on expanding product offerings and exclusive deals that cater to this group’s needs, including household items, electronics, and family-oriented products.
#
# **Increased Focus on Online Shopping:** As shopping trends shift, especially among younger consumers, Walmart should enhance its online shopping experience and mobile app, making it easier for all age groups to shop conveniently and access personalized promotions.
#
# **Leveraging Gender Insights for Inventory Management:** Given the differences in spending behavior between genders, Walmart could optimize inventory and product placement based on gender-specific purchasing trends to increase sales efficiency.
#
# **Continuous Data Analysis:** Establishing a regular analysis framework for purchase behavior will enable Walmart to adapt quickly to changing consumer preferences and market dynamics, ensuring that inventory and marketing strategies remain relevant.
#
#
# **Personalized Shopping Experiences:** Implement personalized marketing strategies based on individual customer data, such as past purchases and preferences. Utilizing targeted emails or app notifications can enhance customer engagement and increase conversion rates.
#
# **Gender-Specific Promotions:** Design promotional campaigns specifically targeting women, especially since their average purchase is slightly lower than men. This could include beauty products, health and wellness items, and fashion apparel, as well as personalized discounts based on their shopping history.
#
# **Product Bundling for Younger Consumers:** Consider creating product bundles that appeal to younger demographics (ages 18-35). For example, combining tech gadgets with accessories or offering family starter packs for new parents can encourage larger transactions.
#
# **Dynamic Pricing Strategies:** Use dynamic pricing strategies that reflect purchasing trends across different demographics. For instance, offering discounts during peak shopping times for specific age groups can drive higher sales volume.
#
# **Local Community Engagement:** Tailor product offerings and promotions based on city categories to better meet local demand. Engaging with community preferences through localized marketing can strengthen brand loyalty and customer retention.
#
# **Enhanced In-Store Experiences:** For high-purchase demographics like ages 26-35, consider enhancing in-store experiences with interactive displays or events that cater to this group, such as product demonstrations, exclusive shopping nights, or themed shopping events.
#
#
# **Social Media Engagement:** Increase presence on platforms where younger demographics engage most. Utilize social media to run contests or promotions that can attract attention and drive traffic to both online and physical stores.
#
# **Feedback Mechanisms:** Establish feedback loops through surveys or social media to gain insights into customer satisfaction and preferences. This data can guide product development and marketing strategies more effectively.
#
# **Sustainability Initiatives:** Promote sustainability efforts, which are increasingly important to consumers, particularly younger shoppers. Highlight eco-friendly products and practices in marketing campaigns to resonate with environmentally conscious consumers.
#
# **Premium and Health Products for Older Shoppers:** Older customers may have preferences for premium, health-related, or convenience-focused items. Highlighting products in these categories through in-store displays or personalized ads could align well with their needs, potentially increasing their average purchase value.
#
# **Enhanced Online Shopping Experience for Female Shoppers:** With female customers showing lower average spend per transaction than male customers, Walmart might consider improving the online shopping experience, especially for popular female-targeted product categories.
#
#
# **Promotional Campaigns in City Category A:** Shoppers from City Category A, who are likely from more urban or affluent areas, may have higher spending potential. Walmart could introduce campaigns that focus on new or high-end products, exclusive offers, and loyalty rewards for these customers, appealing to a likely higher purchasing power.
